# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# reference https://github.com/desihub/LSS/blob/main/scripts/plotting/blinded_DA02_xi02.py
path = '/pscratch/sd/f/forero/MockLSS/FirstGenMocks/AbacusSummit/Y1/mock1/LSScats/corr/smu'
datafile = 'xipoles_LRG_complete_NScomb_0.4_1.1_default_lin5_njack60_nran1_split20.txt'
xi = np.loadtxt(os.path.join(path, datafile)).transpose()
plt.errorbar(xi[0], (xi[0]**2)*xi[2], xi[0]**2.*xi[5])#,fmt=pt,color=cl,label=labeld,mfc=mfc)
#plt.errorbar(xi[0],xi[0]**2*xi[3],xi[0]**2*xi[6])
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
path = '/pscratch/sd/f/forero/MockLSS/FirstGenMocks/AbacusSummit/Y1/mock1/LSScats/corr/smu'
datafile = 'xipoles_ELG_complete_NScomb_0.8_1.1_default_lin5_njack10_nran1_split20.txt'
xi = np.loadtxt(os.path.join(path, datafile)).transpose()
plt.errorbar(xi[0], (xi[0]**2)*xi[2], xi[0]**2.*xi[5])#,fmt=pt,color=cl,label=labeld,mfc=mfc)
#plt.errorbar(xi[0],xi[0]**2*xi[3],xi[0]**2*xi[6])
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
path = '/pscratch/sd/f/forero/MockLSS/FirstGenMocks/AbacusSummit/Y1/mock1/LSScats/corr/smu'
datafile = 'xipoles_QSO_complete_NScomb_0.8_1.1_default_lin5_njack10_nran1_split20.txt'
xi = np.loadtxt(os.path.join(path, datafile)).transpose()
plt.errorbar(xi[0], (xi[0]**2)*xi[2], xi[0]**2.*xi[5])#,fmt=pt,color=cl,label=labeld,mfc=mfc)
#plt.errorbar(xi[0],xi[0]**2*xi[3],xi[0]**2*xi[6])
# Out:
# <ErrorbarContainer object of 3 artists>
