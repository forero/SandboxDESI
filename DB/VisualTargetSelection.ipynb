# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from astropy.io import fits
import numpy as np
import glob

# %%
filenames=glob.glob("../data/decals/*fits")

# %%
fig, ax = pyplot.subplots(figsize=(15, 2))
for filename in filenames:
    print filename
    hdu=fits.open(filename) 
    ra = hdu[1].data['RA']
    dec = hdu[1].data['DEC']
    index = hdu[1].data['TARGETID']
    objtype = hdu[1].data['OBJTYPE']
    qso = where(objtype=='ELG')
    center_ra = hdu[1].header['TILE_RA']
    center_dec = hdu[1].header['TILE_DEC']
    center_id = hdu[1].header['TILE_ID']
    print "center", center_ra, center_dec, center_id
    print "nobj", size(qso)
    scatter(ra[qso],dec[qso],s=0.01)
    print "RA", size(ra)
xlim([318,360])
# Out:
# ../data/decals/Targets_Tile_000096.fits
# center 96 96 96
# nobj 8419
# RA 16709
# ../data/decals/Targets_Tile_000454.fits
# center 454 454 454
# nobj 9480
# RA 18894
# ../data/decals/Targets_Tile_002343.fits
# center 2343 2343 2343
# nobj 7950
# RA 15960
# ../data/decals/Targets_Tile_002344.fits
# center 2344 2344 2344
# nobj 8211
# RA 15461
# ../data/decals/Targets_Tile_002345.fits
# center 2345 2345 2345
# nobj 8040
# RA 14702
# ../data/decals/Targets_Tile_002347.fits
# center 2347 2347 2347
# nobj 9004
# RA 16030
# ../data/decals/Targets_Tile_002350.fits
# center 2350 2350 2350
# nobj 11005
# RA 18699
# ../data/decals/Targets_Tile_002353.fits
# center 2353 2353 2353
# nobj 9120
# RA 17209
# ../data/decals/Targets_Tile_005481.fits
# center 5481 5481 5481
# nobj 8491
# RA 15533
# ../data/decals/Targets_Tile_005483.fits
# center 5483 5483 5483
# nobj 9123
# RA 17612
# ../data/decals/Targets_Tile_005484.fits
# center 5484 5484 5484
# nobj 8831
# RA 16820
# ../data/decals/Targets_Tile_005486.fits
# center 5486 5486 5486
# nobj 11099
# RA 18833
# ../data/decals/Targets_Tile_005487.fits
# center 5487 5487 5487
# nobj 8256
# RA 16055
# ../data/decals/Targets_Tile_005858.fits
# center 5858 5858 5858
# nobj 8284
# RA 16523
# ../data/decals/Targets_Tile_006216.fits
# center 6216 6216 6216
# nobj 9551
# RA 18675
# ../data/decals/Targets_Tile_006237.fits
# center 6237 6237 6237
# nobj 10620
# RA 21164
# ../data/decals/Targets_Tile_008105.fits
# center 8105 8105 8105
# nobj 7948
# RA 15812
# ../data/decals/Targets_Tile_008106.fits
# center 8106 8106 8106
# nobj 7813
# RA 15262
# ../data/decals/Targets_Tile_008107.fits
# center 8107 8107 8107
# nobj 8242
# RA 15096
# ../data/decals/Targets_Tile_008109.fits
# center 8109 8109 8109
# nobj 8548
# RA 15493
# ../data/decals/Targets_Tile_008112.fits
# center 8112 8112 8112
# nobj 10091
# RA 17870
# ../data/decals/Targets_Tile_008115.fits
# center 8115 8115 8115
# nobj 9015
# RA 17106
# ../data/decals/Targets_Tile_011243.fits
# center 11243 11243 11243
# nobj 7865
# RA 14915
# ../data/decals/Targets_Tile_011245.fits
# center 11245 11245 11245
# nobj 9209
# RA 16352
# ../data/decals/Targets_Tile_011246.fits
# center 11246 11246 11246
# nobj 8666
# RA 17548
# ../data/decals/Targets_Tile_011248.fits
# center 11248 11248 11248
# nobj 11172
# RA 19001
# ../data/decals/Targets_Tile_011249.fits
# center 11249 11249 11249
# nobj 8601
# RA 16181
# ../data/decals/Targets_Tile_011620.fits
# center 11620 11620 11620
# nobj 9050
# RA 17187
# ../data/decals/Targets_Tile_011978.fits
# center 11978 11978 11978
# nobj 9532
# RA 18767
# ../data/decals/Targets_Tile_011999.fits
# center 11999 11999 11999
# nobj 11100
# RA 21287
# ../data/decals/Targets_Tile_013867.fits
# center 13867 13867 13867
# nobj 7642
# RA 15236
# ../data/decals/Targets_Tile_013868.fits
# center 13868 13868 13868
# nobj 7995
# RA 15708
# ../data/decals/Targets_Tile_013869.fits
# center 13869 13869 13869
# nobj 8169
# RA 14951
# ../data/decals/Targets_Tile_013871.fits
# center 13871 13871 13871
# nobj 8587
# RA 15495
# ../data/decals/Targets_Tile_013874.fits
# center 13874 13874 13874
# nobj 8784
# RA 16171
# ../data/decals/Targets_Tile_013877.fits
# center 13877 13877 13877
# nobj 8362
# RA 16181
# ../data/decals/Targets_Tile_017005.fits
# center 17005 17005 17005
# nobj 7918
# RA 14677
# ../data/decals/Targets_Tile_017007.fits
# center 17007 17007 17007
# nobj 9362
# RA 16401
# ../data/decals/Targets_Tile_017008.fits
# center 17008 17008 17008
# nobj 8710
# RA 17308
# ../data/decals/Targets_Tile_017010.fits
# center 17010 17010 17010
# nobj 11299
# RA 19062
# ../data/decals/Targets_Tile_017011.fits
# center 17011 17011 17011
# nobj 10234
# RA 17803
# ../data/decals/Targets_Tile_017382.fits
# center 17382 17382 17382
# nobj 9028
# RA 17111
# ../data/decals/Targets_Tile_017740.fits
# center 17740 17740 17740
# nobj 8871
# RA 17976
# ../data/decals/Targets_Tile_017761.fits
# center 17761 17761 17761
# nobj 10453
# RA 20203
# ../data/decals/Targets_Tile_019630.fits
# center 19630 19630 19630
# nobj 8003
# RA 15969
# ../data/decals/Targets_Tile_019631.fits
# center 19631 19631 19631
# nobj 7937
# RA 15362
# ../data/decals/Targets_Tile_019633.fits
# center 19633 19633 19633
# nobj 8094
# RA 15071
# ../data/decals/Targets_Tile_019636.fits
# center 19636 19636 19636
# nobj 9018
# RA 17760
# ../data/decals/Targets_Tile_019639.fits
# center 19639 19639 19639
# nobj 8156
# RA 15846
# ../data/decals/Targets_Tile_022767.fits
# center 22767 22767 22767
# nobj 7993
# RA 14606
# ../data/decals/Targets_Tile_022769.fits
# center 22769 22769 22769
# nobj 8823
# RA 15759
# ../data/decals/Targets_Tile_022770.fits
# center 22770 22770 22770
# nobj 9113
# RA 16819
# ../data/decals/Targets_Tile_022772.fits
# center 22772 22772 22772
# nobj 10680
# RA 18498
# ../data/decals/Targets_Tile_022773.fits
# center 22773 22773 22773
# nobj 11398
# RA 19137
# ../data/decals/Targets_Tile_023144.fits
# center 23144 23144 23144
# nobj 8364
# RA 16203
# ../data/decals/Targets_Tile_023502.fits
# center 23502 23502 23502
# nobj 8547
# RA 16999
# ../data/decals/Targets_Tile_023523.fits
# center 23523 23523 23523
# nobj 9437
# RA 18952
# ../data/decals/Targets_Tile_025392.fits
# center 25392 25392 25392
# nobj 7646
# RA 15289
# ../data/decals/Targets_Tile_025393.fits
# center 25393 25393 25393
# nobj 7954
# RA 15531
# ../data/decals/Targets_Tile_025395.fits
# center 25395 25395 25395
# nobj 7920
# RA 14888
# ../data/decals/Targets_Tile_025398.fits
# center 25398 25398 25398
# nobj 8471
# RA 17068
# ../data/decals/Targets_Tile_025401.fits
# center 25401 25401 25401
# nobj 9665
# RA 17066
# ../data/decals/Targets_Tile_028529.fits
# center 28529 28529 28529
# nobj 8337
# RA 15195
# ../data/decals/Targets_Tile_028531.fits
# center 28531 28531 28531
# nobj 9023
# RA 16031
# ../data/decals/Targets_Tile_028532.fits
# center 28532 28532 28532
# nobj 9279
# RA 16273
# ../data/decals/Targets_Tile_028534.fits
# center 28534 28534 28534
# nobj 9435
# RA 17029
# ../data/decals/Targets_Tile_028535.fits
# center 28535 28535 28535
# nobj 11222
# RA 19173
# (318, 360)
