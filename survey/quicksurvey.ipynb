# %%
# %pylab inline
# %reload_ext autoreload
# %autoreload 2
import sys
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sys.path.insert(0, '/home/forero/desihub/desimodel/py/')
sys.path.insert(0, '/home/forero/desihub/desisurvey/py/')

# %%
import desimodel.io
import desimodel.positioner
import desisurvey.targets

# %%
fiberpos = desimodel.io.load_fiberpos()

# %%
positioner = desimodel.positioner.Positioner()

# %%
positioner.Ei
# Out:
# 6.8

# %%
target_tile = desisurvey.targets.TargetTile("/home/forero/desihub/SandboxDESI/data/galform/Targets_Tile_002952.fits")

# %%
scatter(target_tile.ra, target_tile.dec,s=0.1)

# %%
tiles = ["/home/forero/desihub/SandboxDESI/data/galform/Targets_Tile_002952.fits",
        "/home/forero/desihub/SandboxDESI/data/galform/Targets_Tile_002953.fits",
        "/home/forero/desihub/SandboxDESI/data/galform/Targets_Tile_002968.fits"]

# %%
targets_survey = desisurvey.targets.TargetSurvey(tiles)
# Out:
# Adding /home/forero/desihub/SandboxDESI/data/galform/Targets_Tile_002952.fits to build TargetSurvey 3 files to go
# Adding /home/forero/desihub/SandboxDESI/data/galform/Targets_Tile_002953.fits to build TargetSurvey 2 files to go
# Adding /home/forero/desihub/SandboxDESI/data/galform/Targets_Tile_002968.fits to build TargetSurvey 1 files to go

# %%
scatter(targets_survey.ra, targets_survey.dec, s=0.1)
