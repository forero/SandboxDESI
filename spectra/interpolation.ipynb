# %%
import numpy as np
import matplotlib.pyplot as plt
from desisim.io import read_basis_templates
# %matplotlib inline

# %%
baseflux, basewave, basemeta = read_basis_templates(objtype='STAR')
# Out:
# INFO:io.py:611:read_basis_templates: Reading /home/forero/desidata/spectro/templates/basis_templates/v2.2/star_templates_v2.1.fits
# INFO:DESI:Reading /home/forero/desidata/spectro/templates/basis_templates/v2.2/star_templates_v2.1.fits

# %%
plt.scatter(basemeta['TEFF'],basemeta['LOGG'])
plt.grid()
plt.xlabel('TEFF')
plt.ylabel('LOGG')

# %%
plt.scatter(basemeta['TEFF'],basemeta['FEH'])
plt.grid()
plt.xlabel('TEFF')
plt.ylabel('FEH')

# %%
plt.scatter(basemeta['LOGG'],basemeta['FEH'])
plt.grid()
plt.xlabel('LOGG')
plt.ylabel('FEH')
