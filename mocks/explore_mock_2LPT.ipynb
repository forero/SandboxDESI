# %%
import h5py 
import numpy as np
import os
import glob
from astropy.table import Table
import desimodel.footprint

# %%
names = {'sources1':'LRG', 'sources2':'ELG', 'sources3':'QSO'}
datafields = ['RA', 'DEC', 'Z_COSMO', 'DZ_RSD']
summary = {}
for name in names.keys():
    summary[names[name]] = {}
    for field in datafields:
        summary[names[name]][field] = np.empty((0))

# %%
datapath = '/global/project/projectdirs/desi/mocks/GaussianRandomField/v0.0.6_2LPT'
datafiles = glob.glob(datapath+"/*.h5")

# %%
for datafile in datafiles:
    f = h5py.File(datafile, "r")
    for source in names.keys():
        s = f[source]
        for field in datafields:
            data = s[field]
            print(source, field, len(data), type(data))
            if len(data)>0 :
                summary[names[source]][field] = np.append(summary[names[source]][field], data)
# Out:
# sources3 RA 79405 <class 'numpy.ndarray'>
# sources3 DEC 79405 <class 'numpy.ndarray'>
# sources3 Z_COSMO 79405 <class 'numpy.ndarray'>
# sources3 DZ_RSD 79405 <class 'numpy.ndarray'>
# sources2 RA 367151 <class 'numpy.ndarray'>
# sources2 DEC 367151 <class 'numpy.ndarray'>
# sources2 Z_COSMO 367151 <class 'numpy.ndarray'>
# sources2 DZ_RSD 367151 <class 'numpy.ndarray'>
# sources1 RA 0 <class 'numpy.ndarray'>
# sources1 DEC 0 <class 'numpy.ndarray'>
# sources1 Z_COSMO 0 <class 'numpy.ndarray'>
# sources1 DZ_RSD 0 <class 'numpy.ndarray'>
# sources3 RA 214805 <class 'numpy.ndarray'>
# sources3 DEC 214805 <class 'numpy.ndarray'>
# sources3 Z_COSMO 214805 <class 'numpy.ndarray'>
# sources3 DZ_RSD 214805 <class 'numpy.ndarray'>
# sources2 RA 2553940 <class 'numpy.ndarray'>
# sources2 DEC 2553940 <class 'numpy.ndarray'>
# sources2 Z_COSMO 2553940 <class 'numpy.ndarray'>
# sources2 DZ_RSD 2553940 <class 'numpy.ndarray'>
# sources1 RA 1734 <class 'numpy.ndarray'>
# sources1 DEC 1734 <class 'numpy.ndarray'>
# sources1 Z_COSMO 1734 <class 'numpy.ndarray'>
# sources1 DZ_RSD 1734 <class 'numpy.ndarray'>
# sources3 RA 557950 <class 'numpy.ndarray'>
# sources3 DEC 557950 <class 'numpy.ndarray'>
# sources3 Z_COSMO 557950 <class 'numpy.ndarray'>
# sources3 DZ_RSD 557950 <class 'numpy.ndarray'>
# sources2 RA 18553427 <class 'numpy.ndarray'>
# sources2 DEC 18553427 <class 'numpy.ndarray'>
# sources2 Z_COSMO 18553427 <class 'numpy.ndarray'>
# sources2 DZ_RSD 18553427 <class 'numpy.ndarray'>
# sources1 RA 3299082 <class 'numpy.ndarray'>
# sources1 DEC 3299082 <class 'numpy.ndarray'>
# sources1 Z_COSMO 3299082 <class 'numpy.ndarray'>
# sources1 DZ_RSD 3299082 <class 'numpy.ndarray'>
# sources3 RA 646761 <class 'numpy.ndarray'>
# sources3 DEC 646761 <class 'numpy.ndarray'>
# sources3 Z_COSMO 646761 <class 'numpy.ndarray'>
# sources3 DZ_RSD 646761 <class 'numpy.ndarray'>
# sources2 RA 18549687 <class 'numpy.ndarray'>
# sources2 DEC 18549687 <class 'numpy.ndarray'>
# sources2 Z_COSMO 18549687 <class 'numpy.ndarray'>
# sources2 DZ_RSD 18549687 <class 'numpy.ndarray'>
# sources1 RA 3297131 <class 'numpy.ndarray'>
# sources1 DEC 3297131 <class 'numpy.ndarray'>
# sources1 Z_COSMO 3297131 <class 'numpy.ndarray'>
# sources1 DZ_RSD 3297131 <class 'numpy.ndarray'>
# sources3 RA 322892 <class 'numpy.ndarray'>
# sources3 DEC 322892 <class 'numpy.ndarray'>
# sources3 Z_COSMO 322892 <class 'numpy.ndarray'>
# sources3 DZ_RSD 322892 <class 'numpy.ndarray'>
# sources2 RA 7503891 <class 'numpy.ndarray'>
# sources2 DEC 7503891 <class 'numpy.ndarray'>
# sources2 Z_COSMO 7503891 <class 'numpy.ndarray'>
# sources2 DZ_RSD 7503891 <class 'numpy.ndarray'>
# sources1 RA 127186 <class 'numpy.ndarray'>
# sources1 DEC 127186 <class 'numpy.ndarray'>
# sources1 Z_COSMO 127186 <class 'numpy.ndarray'>
# sources1 DZ_RSD 127186 <class 'numpy.ndarray'>
# sources3 RA 480733 <class 'numpy.ndarray'>
# sources3 DEC 480733 <class 'numpy.ndarray'>
# sources3 Z_COSMO 480733 <class 'numpy.ndarray'>
# sources3 DZ_RSD 480733 <class 'numpy.ndarray'>
# sources2 RA 18377652 <class 'numpy.ndarray'>
# sources2 DEC 18377652 <class 'numpy.ndarray'>
# sources2 Z_COSMO 18377652 <class 'numpy.ndarray'>
# sources2 DZ_RSD 18377652 <class 'numpy.ndarray'>
# sources1 RA 3090250 <class 'numpy.ndarray'>
# sources1 DEC 3090250 <class 'numpy.ndarray'>
# sources1 Z_COSMO 3090250 <class 'numpy.ndarray'>
# sources1 DZ_RSD 3090250 <class 'numpy.ndarray'>
# sources3 RA 80011 <class 'numpy.ndarray'>
# sources3 DEC 80011 <class 'numpy.ndarray'>
# sources3 Z_COSMO 80011 <class 'numpy.ndarray'>
# sources3 DZ_RSD 80011 <class 'numpy.ndarray'>
# sources2 RA 366297 <class 'numpy.ndarray'>
# sources2 DEC 366297 <class 'numpy.ndarray'>
# sources2 Z_COSMO 366297 <class 'numpy.ndarray'>
# sources2 DZ_RSD 366297 <class 'numpy.ndarray'>
# sources1 RA 0 <class 'numpy.ndarray'>
# sources1 DEC 0 <class 'numpy.ndarray'>
# sources1 Z_COSMO 0 <class 'numpy.ndarray'>
# sources1 DZ_RSD 0 <class 'numpy.ndarray'>
# sources3 RA 558236 <class 'numpy.ndarray'>
# sources3 DEC 558236 <class 'numpy.ndarray'>
# sources3 Z_COSMO 558236 <class 'numpy.ndarray'>
# sources3 DZ_RSD 558236 <class 'numpy.ndarray'>
# sources2 RA 18550703 <class 'numpy.ndarray'>
# sources2 DEC 18550703 <class 'numpy.ndarray'>
# sources2 Z_COSMO 18550703 <class 'numpy.ndarray'>
# sources2 DZ_RSD 18550703 <class 'numpy.ndarray'>
# sources1 RA 3286400 <class 'numpy.ndarray'>
# sources1 DEC 3286400 <class 'numpy.ndarray'>
# sources1 Z_COSMO 3286400 <class 'numpy.ndarray'>
# sources1 DZ_RSD 3286400 <class 'numpy.ndarray'>
# sources3 RA 715923 <class 'numpy.ndarray'>
# sources3 DEC 715923 <class 'numpy.ndarray'>
# sources3 Z_COSMO 715923 <class 'numpy.ndarray'>
# sources3 DZ_RSD 715923 <class 'numpy.ndarray'>
# sources2 RA 18574758 <class 'numpy.ndarray'>
# sources2 DEC 18574758 <class 'numpy.ndarray'>
# sources2 Z_COSMO 18574758 <class 'numpy.ndarray'>
# sources2 DZ_RSD 18574758 <class 'numpy.ndarray'>
# sources1 RA 3302509 <class 'numpy.ndarray'>
# sources1 DEC 3302509 <class 'numpy.ndarray'>
# sources1 Z_COSMO 3302509 <class 'numpy.ndarray'>
# sources1 DZ_RSD 3302509 <class 'numpy.ndarray'>
# sources3 RA 323006 <class 'numpy.ndarray'>
# sources3 DEC 323006 <class 'numpy.ndarray'>
# sources3 Z_COSMO 323006 <class 'numpy.ndarray'>
# sources3 DZ_RSD 323006 <class 'numpy.ndarray'>
# sources2 RA 7521452 <class 'numpy.ndarray'>
# sources2 DEC 7521452 <class 'numpy.ndarray'>
# sources2 Z_COSMO 7521452 <class 'numpy.ndarray'>
# sources2 DZ_RSD 7521452 <class 'numpy.ndarray'>
# sources1 RA 128711 <class 'numpy.ndarray'>
# sources1 DEC 128711 <class 'numpy.ndarray'>
# sources1 Z_COSMO 128711 <class 'numpy.ndarray'>
# sources1 DZ_RSD 128711 <class 'numpy.ndarray'>
# sources3 RA 214815 <class 'numpy.ndarray'>
# sources3 DEC 214815 <class 'numpy.ndarray'>
# sources3 Z_COSMO 214815 <class 'numpy.ndarray'>
# sources3 DZ_RSD 214815 <class 'numpy.ndarray'>
# sources2 RA 2555912 <class 'numpy.ndarray'>
# sources2 DEC 2555912 <class 'numpy.ndarray'>
# sources2 Z_COSMO 2555912 <class 'numpy.ndarray'>
# sources2 DZ_RSD 2555912 <class 'numpy.ndarray'>
# sources1 RA 1687 <class 'numpy.ndarray'>
# sources1 DEC 1687 <class 'numpy.ndarray'>
# sources1 Z_COSMO 1687 <class 'numpy.ndarray'>
# sources1 DZ_RSD 1687 <class 'numpy.ndarray'>
# sources3 RA 408807 <class 'numpy.ndarray'>
# sources3 DEC 408807 <class 'numpy.ndarray'>
# sources3 Z_COSMO 408807 <class 'numpy.ndarray'>
# sources3 DZ_RSD 408807 <class 'numpy.ndarray'>
# sources2 RA 14494724 <class 'numpy.ndarray'>
# sources2 DEC 14494724 <class 'numpy.ndarray'>
# sources2 Z_COSMO 14494724 <class 'numpy.ndarray'>
# sources2 DZ_RSD 14494724 <class 'numpy.ndarray'>
# sources1 RA 1330506 <class 'numpy.ndarray'>
# sources1 DEC 1330506 <class 'numpy.ndarray'>
# sources1 Z_COSMO 1330506 <class 'numpy.ndarray'>
# sources1 DZ_RSD 1330506 <class 'numpy.ndarray'>
# sources3 RA 407405 <class 'numpy.ndarray'>
# sources3 DEC 407405 <class 'numpy.ndarray'>
# sources3 Z_COSMO 407405 <class 'numpy.ndarray'>
# sources3 DZ_RSD 407405 <class 'numpy.ndarray'>
# sources2 RA 14499106 <class 'numpy.ndarray'>
# sources2 DEC 14499106 <class 'numpy.ndarray'>
# sources2 Z_COSMO 14499106 <class 'numpy.ndarray'>
# sources2 DZ_RSD 14499106 <class 'numpy.ndarray'>
# sources1 RA 1333117 <class 'numpy.ndarray'>
# sources1 DEC 1333117 <class 'numpy.ndarray'>
# sources1 Z_COSMO 1333117 <class 'numpy.ndarray'>
# sources1 DZ_RSD 1333117 <class 'numpy.ndarray'>
# sources3 RA 713656 <class 'numpy.ndarray'>
# sources3 DEC 713656 <class 'numpy.ndarray'>
# sources3 Z_COSMO 713656 <class 'numpy.ndarray'>
# sources3 DZ_RSD 713656 <class 'numpy.ndarray'>
# sources2 RA 18548773 <class 'numpy.ndarray'>
# sources2 DEC 18548773 <class 'numpy.ndarray'>
# sources2 Z_COSMO 18548773 <class 'numpy.ndarray'>
# sources2 DZ_RSD 18548773 <class 'numpy.ndarray'>
# sources1 RA 3287913 <class 'numpy.ndarray'>
# sources1 DEC 3287913 <class 'numpy.ndarray'>
# sources1 Z_COSMO 3287913 <class 'numpy.ndarray'>
# sources1 DZ_RSD 3287913 <class 'numpy.ndarray'>
# sources3 RA 480407 <class 'numpy.ndarray'>
# sources3 DEC 480407 <class 'numpy.ndarray'>
# sources3 Z_COSMO 480407 <class 'numpy.ndarray'>
# sources3 DZ_RSD 480407 <class 'numpy.ndarray'>
# sources2 RA 18362053 <class 'numpy.ndarray'>
# sources2 DEC 18362053 <class 'numpy.ndarray'>
# sources2 Z_COSMO 18362053 <class 'numpy.ndarray'>
# sources2 DZ_RSD 18362053 <class 'numpy.ndarray'>
# sources1 RA 3096614 <class 'numpy.ndarray'>
# sources1 DEC 3096614 <class 'numpy.ndarray'>
# sources1 Z_COSMO 3096614 <class 'numpy.ndarray'>
# sources1 DZ_RSD 3096614 <class 'numpy.ndarray'>
# sources3 RA 648253 <class 'numpy.ndarray'>
# sources3 DEC 648253 <class 'numpy.ndarray'>
# sources3 Z_COSMO 648253 <class 'numpy.ndarray'>
# sources3 DZ_RSD 648253 <class 'numpy.ndarray'>
# sources2 RA 18552249 <class 'numpy.ndarray'>
# sources2 DEC 18552249 <class 'numpy.ndarray'>
# sources2 Z_COSMO 18552249 <class 'numpy.ndarray'>
# sources2 DZ_RSD 18552249 <class 'numpy.ndarray'>
# sources1 RA 3302261 <class 'numpy.ndarray'>
# sources1 DEC 3302261 <class 'numpy.ndarray'>
# sources1 Z_COSMO 3302261 <class 'numpy.ndarray'>
# sources1 DZ_RSD 3302261 <class 'numpy.ndarray'>

# %%
desitiles = desimodel.io.load_tiles()
for source in names.values():
    indesi = desimodel.footprint.is_point_in_desi(desitiles, summary[source]['RA'], summary[source]['DEC'])
    for field in datafields:
        data = summary[source][field] 
        summary[source][field] = data[indesi]

# %%
for source in names.values():
    Table(summary[source]).write(source+'.fits', overwrite=True)
