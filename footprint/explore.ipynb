# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import desimodel.io
from astropy.table import Table

# %%
tiles = Table(desimodel.io.load_tiles())

# %%
set(tiles['PASS'][tiles['PROGRAM']=='GRAY'])
# Out:
# {0}

# %%
set(tiles['PASS'][tiles['PROGRAM']=='DARK'])
# Out:
# {1, 2, 3, 4}

# %%
set(tiles['PASS'][tiles['PROGRAM']=='BRIGHT'])
# Out:
# {5, 6, 7}

# %%
ii = tiles['PASS']==0
plt.scatter(tiles['RA'][ii], tiles['DEC'][ii], alpha=0.5)
